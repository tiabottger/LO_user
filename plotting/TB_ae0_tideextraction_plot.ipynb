# %%
import numpy as np
import xarray as xr
import pickle
from datetime import datetime, timedelta
import pandas as pd
import sys

from lo_tools import Lfun, zfun, zrfun
from lo_tools import plotting_functions as pfun
import pinfo
from importlib import reload
reload(pfun)
reload(pinfo)

Ldir = Lfun.Lstart()
if '_mac' in Ldir['lo_env']: # mac version
    pass
else: # remote linux version
    import matplotlib as mpl
    mpl.use('Agg')
import matplotlib.pyplot as plt

from cmocean import cm # have to import after matplotlib to work on remote machine

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# check tidal forcing on boundary
ds = xr.open_dataset('~/LO_output/extract/ae0_tnoriv_xa0/moor/ae0/boundary_2020.01.01_2020.01.15.nc')

ds.zeta.plot(figsize=(10, 4))
plt.title("Sea Surface Height (zeta)")
plt.xlabel("Time")
plt.ylabel("zeta (m)")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

ds_boundary = xr.open_dataset('~/LO_output/extract/ae0_tnoriv_xa0/moor/ae0/boundary_2020.01.01_2020.01.15.nc')
ds_est_middle = xr.open_dataset('~/LO_output/extract/ae0_tnoriv_xa0/moor/ae0/est_middle_2020.01.01_2020.01.15.nc')
ds_est_mouth = xr.open_dataset('~/LO_output/extract/ae0_tnoriv_xa0/moor/ae0/est_mouth_2020.01.01_2020.01.15.nc')
ds_ocean = xr.open_dataset('~/LO_output/extract/ae0_tnoriv_xa0/moor/ae0/ocean_2020.01.01_2020.01.15.nc')
ds_river = xr.open_dataset('~/LO_output/extract/ae0_tnoriv_xa0/moor/ae0/river_2020.01.01_2020.01.15.nc')

ds.zeta.plot(figsize=(10, 4))
# plot datasets
ds_ocean.zeta.plot(label='Ocean', color='blue')
ds_est_mouth.zeta.plot(label='Estuary Mouth', color='purple')
ds_est_middle.zeta.plot(label='Estuary Middle',color='orange')
ds_river.zeta.plot(label='Estuary End', color='red')

plt.title("Sea Surface Height (zeta)")
plt.xlabel("Time")
plt.ylabel("zeta (m)")
plt.legend()
plt.grid(True)

plt.show()
